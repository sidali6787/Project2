# %%
import pandas as pd
import pymongo

# %% [markdown]
# # Extraction

# %%
df = pd.read_csv('Data/Independents100.csv')
df.head()
# Out:
#    Rank                     Restaurant       Sales  Average Check  \
# 0    34                  Bottega Louie  18521000.0             36
# 1    40        Original Joe's Westlake  18159612.0             35
# 2    47  Harris Ranch Inn & Restaurant  17599468.0             29
# 3    63                     China Live  15106280.0             54
# 4    71                    Cliff House  14465847.0             40
#
#             City State  Meals Served
# 0    Los Angeles    CA      322562.0
# 1      Daly City    CA      473492.0
# 2       Coalinga    CA      611928.0
# 3  San Francisco    CA      300000.0
# 4  San Francisco    CA      199901.0

# %% [markdown]
# # Transfom

# %%
df1 = df.set_index('Rank').sort_index()
df1.head()
# Out:
#                                Restaurant       Sales  Average Check  \
# Rank
# 1                Carmine's (Times Square)  39080335.0             40
# 2                   The Boathouse Orlando  35218364.0             43
# 3                        Old Ebbitt Grill  29104017.0             33
# 4     LAVO Italian Restaurant & Nightclub  26916180.0             90
# 5                Bryant Park Grill & Cafe  26900000.0             62
#
#             City State  Meals Served
# Rank
# 1       New York    NY      469803.0
# 2       Orlando     FL      820819.0
# 3     Washington    DC      892830.0
# 4       New York    NY      198500.0
# 5       New York    NY      403000.0

# %% [markdown]
# # Load

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
db = client.project2_db
restaurantes = db.retaurantes
restaurantes.insert_many(df1.to_dict(orient='records'))

# %%
# Out:
# [{'Restaurant': "Carmine's (Times Square)",
#   'Sales': 39080335.0,
#   'Average Check': 40,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 469803.0},
#  {'Restaurant': 'The Boathouse Orlando',
#   'Sales': 35218364.0,
#   'Average Check': 43,
#   'City': 'Orlando ',
#   'State': 'FL',
#   'Meals Served': 820819.0},
#  {'Restaurant': 'Old Ebbitt Grill',
#   'Sales': 29104017.0,
#   'Average Check': 33,
#   'City': 'Washington',
#   'State': 'DC',
#   'Meals Served': 892830.0},
#  {'Restaurant': 'LAVO Italian Restaurant & Nightclub',
#   'Sales': 26916180.0,
#   'Average Check': 90,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 198500.0},
#  {'Restaurant': 'Bryant Park Grill & Cafe',
#   'Sales': 26900000.0,
#   'Average Check': 62,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 403000.0},
#  {'Restaurant': 'Gibsons Bar & Steakhouse',
#   'Sales': 25409952.0,
#   'Average Check': 80,
#   'City': 'Chicago',
#   'State': 'IL',
#   'Meals Served': 348567.0},
#  {'Restaurant': 'Top of the World at the STRAT ',
#   'Sales': 25233543.0,
#   'Average Check': 103,
#   'City': 'Las Vegas',
#   'State': 'NV',
#   'Meals Served': 246054.0},
#  {'Restaurant': 'Maple & Ash',
#   'Sales': 24837595.0,
#   'Average Check': 99,
#   'City': 'Chicago',
#   'State': 'IL',
#   'Meals Served': 210832.0},
#  {'Restaurant': 'Balthazar',
#   'Sales': 24547800.0,
#   'Average Check': 87,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 519000.0},
#  {'Restaurant': 'Smith & Wollensky',
#   'Sales': 24501000.0,
#   'Average Check': 107,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 257364.0},
#  {'Restaurant': 'Angus Barn',
#   'Sales': 24268160.0,
#   'Average Check': 75,
#   'City': 'Raleigh',
#   'State': 'NC',
#   'Meals Served': 315000.0},
#  {'Restaurant': 'Prime 112',
#   'Sales': 23800000.0,
#   'Average Check': 135,
#   'City': 'Miami Beach',
#   'State': 'FL',
#   'Meals Served': 206000.0},
#  {'Restaurant': "Joe's Seafood, Prime Steak & Stone Crab",
#   'Sales': 23660000.0,
#   'Average Check': 86,
#   'City': 'Washington',
#   'State': 'DC',
#   'Meals Served': 277850.0},
#  {'Restaurant': "Junior's (Times Square)",
#   'Sales': 23640652.0,
#   'Average Check': 23,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 914500.0},
#  {'Restaurant': 'The Hamilton',
#   'Sales': 23138062.0,
#   'Average Check': 33,
#   'City': 'Washington',
#   'State': 'DC',
#   'Meals Served': 700861.0},
#  {'Restaurant': "Joe's Seafood, Prime Steak & Stone Crab",
#   'Sales': 22981600.0,
#   'Average Check': 91,
#   'City': 'Chicago',
#   'State': 'IL',
#   'Meals Served': 252500.0},
#  {'Restaurant': "Joe's Seafood, Prime Steak & Stone Crab",
#   'Sales': 22859400.0,
#   'Average Check': 81,
#   'City': 'Las Vegas',
#   'State': 'NV',
#   'Meals Served': 286000.0},
#  {'Restaurant': 'Gibsons Italia',
#   'Sales': 22749232.0,
#   'Average Check': 108,
#   'City': 'Chicago',
#   'State': 'IL',
#   'Meals Served': 252962.0},
#  {'Restaurant': 'Komodo',
#   'Sales': 22500000.0,
#   'Average Check': 98,
#   'City': 'Miami',
#   'State': 'FL',
#   'Meals Served': 265000.0},
#  {'Restaurant': 'Buddakan',
#   'Sales': 22395577.0,
#   'Average Check': 67,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 221059.0},
#  {'Restaurant': 'Bazaar Meat by Jose Andres',
#   'Sales': 22181607.0,
#   'Average Check': 119,
#   'City': 'Las Vegas',
#   'State': 'NV',
#   'Meals Served': 190000.0},
#  {'Restaurant': 'SW Steakhouse',
#   'Sales': 21523650.0,
#   'Average Check': 149,
#   'City': 'Las Vegas',
#   'State': 'NV',
#   'Meals Served': 145700.0},
#  {'Restaurant': 'St. Elmo Steak House',
#   'Sales': 21422141.0,
#   'Average Check': 99,
#   'City': 'Indianapolis',
#   'State': 'IN',
#   'Meals Served': 192774.0},
#  {'Restaurant': 'RPM Steak',
#   'Sales': 20853300.0,
#   'Average Check': 102,
#   'City': 'Chicago',
#   'State': 'IL',
#   'Meals Served': 202900.0},
#  {'Restaurant': 'Mon Ami Gabi',
#   'Sales': 20120210.0,
#   'Average Check': 76,
#   'City': 'Las Vegas',
#   'State': 'NV',
#   'Meals Served': 319200.0},
#  {'Restaurant': 'Gibsons Bar & Steakhouse',
#   'Sales': 19831818.0,
#   'Average Check': 81,
#   'City': 'Oak Brook',
#   'State': 'IL',
#   'Meals Served': 276444.0},
#  {'Restaurant': 'Paddlefish',
#   'Sales': 19829500.0,
#   'Average Check': 48,
#   'City': 'Orlando ',
#   'State': 'FL',
#   'Meals Served': 417500.0},
#  {'Restaurant': 'Taste of Texas',
#   'Sales': 19530159.0,
#   'Average Check': 55,
#   'City': 'Houston',
#   'State': 'TX',
#   'Meals Served': 375241.0},
#  {'Restaurant': 'Parc',
#   'Sales': 19379153.0,
#   'Average Check': 35,
#   'City': 'Philadelphia',
#   'State': 'PA',
#   'Meals Served': 486219.0},
#  {'Restaurant': "Bob Chinn's Crab House",
#   'Sales': 18687601.0,
#   'Average Check': 48,
#   'City': 'Wheeling',
#   'State': 'IL',
#   'Meals Served': 625907.0},
#  {'Restaurant': 'Quality Meats',
#   'Sales': 18678000.0,
#   'Average Check': 115,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 165148.0},
#  {'Restaurant': 'Del Posto',
#   'Sales': 18625033.0,
#   'Average Check': 194,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 95000.0},
#  {'Restaurant': 'Shooters Waterfront',
#   'Sales': 18601433.0,
#   'Average Check': 57,
#   'City': 'Ft. Lauderdale',
#   'State': 'FL',
#   'Meals Served': 409752.0},
#  {'Restaurant': 'Bottega Louie',
#   'Sales': 18521000.0,
#   'Average Check': 36,
#   'City': 'Los Angeles',
#   'State': 'CA',
#   'Meals Served': 322562.0},
#  {'Restaurant': 'Le Diplomate',
#   'Sales': 18490719.0,
#   'Average Check': 38,
#   'City': 'Washington',
#   'State': 'DC',
#   'Meals Served': 363609.0},
#  {'Restaurant': 'Gibsons Bar & Steakhouse',
#   'Sales': 18483056.0,
#   'Average Check': 79,
#   'City': 'Rosemont',
#   'State': 'IL',
#   'Meals Served': 252419.0},
#  {'Restaurant': 'Lavo Italian Restaurant & Lounge',
#   'Sales': 18386262.0,
#   'Average Check': 97,
#   'City': 'Las Vegas',
#   'State': 'NV',
#   'Meals Served': 115500.0},
#  {'Restaurant': 'Prime Steakhouse',
#   'Sales': 18248030.0,
#   'Average Check': 173,
#   'City': 'Las Vegas',
#   'State': 'NV',
#   'Meals Served': 113600.0},
#  {'Restaurant': 'Makoto',
#   'Sales': 18216906.0,
#   'Average Check': 54,
#   'City': 'Bal Harbour',
#   'State': 'FL',
#   'Meals Served': 256830.0},
#  {'Restaurant': "Original Joe's Westlake",
#   'Sales': 18159612.0,
#   'Average Check': 35,
#   'City': 'Daly City',
#   'State': 'CA',
#   'Meals Served': 473492.0},
#  {'Restaurant': "Shaw's Crab House",
#   'Sales': 17965500.0,
#   'Average Check': 72,
#   'City': 'Chicago',
#   'State': 'IL',
#   'Meals Served': 270000.0},
#  {'Restaurant': 'Founding Farmers (Washington, D.C.)',
#   'Sales': 17910045.0,
#   'Average Check': 33,
#   'City': 'Washington',
#   'State': 'DC',
#   'Meals Served': 648096.0},
#  {'Restaurant': "Junior's (49th Street)",
#   'Sales': 17834390.0,
#   'Average Check': 22,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 798000.0},
#  {'Restaurant': 'Chops Lobster Bar',
#   'Sales': 17816450.0,
#   'Average Check': 106,
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Meals Served': 168000.0},
#  {'Restaurant': 'Chicago Cut Steakhouse',
#   'Sales': 17743720.0,
#   'Average Check': 95,
#   'City': 'Chicago',
#   'State': 'IL',
#   'Meals Served': 211000.0},
#  {'Restaurant': 'Swift & Sons',
#   'Sales': 17637400.0,
#   'Average Check': 119,
#   'City': 'Chicago',
#   'State': 'IL',
#   'Meals Served': 195343.0},
#  {'Restaurant': 'Harris Ranch Inn & Restaurant',
#   'Sales': 17599468.0,
#   'Average Check': 29,
#   'City': 'Coalinga',
#   'State': 'CA',
#   'Meals Served': 611928.0},
#  {'Restaurant': 'Sparks Steak House',
#   'Sales': 17519030.0,
#   'Average Check': 100,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 198200.0},
#  {'Restaurant': 'Quality Italian',
#   'Sales': 17519000.0,
#   'Average Check': 95,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 177337.0},
#  {'Restaurant': 'Frankenmuth Bavarian Inn',
#   'Sales': 17388751.0,
#   'Average Check': 19,
#   'City': 'Frankenmuth',
#   'State': 'MI',
#   'Meals Served': 899284.0},
#  {'Restaurant': 'Tavern on the Green',
#   'Sales': 17212800.0,
#   'Average Check': 76,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 250000.0},
#  {'Restaurant': "Abe & Louie's",
#   'Sales': 17063477.0,
#   'Average Check': 106,
#   'City': 'Boston',
#   'State': 'MA',
#   'Meals Served': 160762.0},
#  {'Restaurant': 'Rusty Pelican',
#   'Sales': 16981741.0,
#   'Average Check': 98,
#   'City': 'Miami',
#   'State': 'FL',
#   'Meals Served': 182000.0},
#  {'Restaurant': 'Beauty & Essex (New York City)',
#   'Sales': 16364050.0,
#   'Average Check': 90,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 187970.0},
#  {'Restaurant': 'Grand Central Oyster Bar',
#   'Sales': 16304883.0,
#   'Average Check': 62,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 296000.0},
#  {'Restaurant': 'Delmonico Steakhouse',
#   'Sales': 16154000.0,
#   'Average Check': 103,
#   'City': 'Las Vegas',
#   'State': 'NV',
#   'Meals Served': 133000.0},
#  {'Restaurant': 'Portland City Grill',
#   'Sales': 16111510.0,
#   'Average Check': 83,
#   'City': 'Portland',
#   'State': 'OR',
#   'Meals Served': 268062.0},
#  {'Restaurant': "Zehnder's of Frankenmuth",
#   'Sales': 16063684.0,
#   'Average Check': 17,
#   'City': 'Frankenmuth',
#   'State': 'MI',
#   'Meals Served': 959026.0},
#  {'Restaurant': 'The Rustic Inn',
#   'Sales': 15700000.0,
#   'Average Check': 43,
#   'City': 'Ft. Lauderdale',
#   'State': 'FL',
#   'Meals Served': 371000.0},
#  {'Restaurant': "Harry Caray's Italian Steakhouse",
#   'Sales': 15680000.0,
#   'Average Check': 59,
#   'City': 'Chicago',
#   'State': 'IL',
#   'Meals Served': 287900.0},
#  {'Restaurant': 'Keens Steakhouse',
#   'Sales': 15629700.0,
#   'Average Check': 97,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 168301.0},
#  {'Restaurant': 'The Lobster House',
#   'Sales': 15450000.0,
#   'Average Check': 43,
#   'City': 'Cape May',
#   'State': 'NJ',
#   'Meals Served': 320000.0},
#  {'Restaurant': 'China Live',
#   'Sales': 15106280.0,
#   'Average Check': 54,
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Meals Served': 300000.0},
#  {'Restaurant': 'Prime & Provisions',
#   'Sales': 15100000.0,
#   'Average Check': 130,
#   'City': 'Chicago',
#   'State': 'IL',
#   'Meals Served': 116154.0},
#  {'Restaurant': "Carmine's (Las Vegas)",
#   'Sales': 15067804.0,
#   'Average Check': 45,
#   'City': 'Las Vegas',
#   'State': 'NV',
#   'Meals Served': 176221.0},
#  {'Restaurant': 'Swan',
#   'Sales': 15000000.0,
#   'Average Check': 78,
#   'City': 'Miami',
#   'State': 'FL',
#   'Meals Served': 225000.0},
#  {'Restaurant': '15th Street Fisheries',
#   'Sales': 14978103.0,
#   'Average Check': 69,
#   'City': 'Fort Lauderdale',
#   'State': 'FL',
#   'Meals Served': 356000.0},
#  {'Restaurant': 'Atlanta Fish Market',
#   'Sales': 14972300.0,
#   'Average Check': 57,
#   'City': 'Atlanta',
#   'State': 'GA',
#   'Meals Served': 274000.0},
#  {'Restaurant': 'Acme Feed & Seed',
#   'Sales': 14897125.0,
#   'Average Check': 22,
#   'City': 'Nashville',
#   'State': 'TN',
#   'Meals Served': 527130.0},
#  {'Restaurant': "Hugo's Frog Bar & Fish House",
#   'Sales': 14790123.0,
#   'Average Check': 80,
#   'City': 'Chicago',
#   'State': 'IL',
#   'Meals Served': 190616.0},
#  {'Restaurant': 'Cliff House',
#   'Sales': 14465847.0,
#   'Average Check': 40,
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Meals Served': 199901.0},
#  {'Restaurant': 'Castaway Burbank',
#   'Sales': 14407413.0,
#   'Average Check': 60,
#   'City': 'Burbank',
#   'State': 'CA',
#   'Meals Served': 180320.0},
#  {'Restaurant': "Matt's El Rancho",
#   'Sales': 14381904.0,
#   'Average Check': 29,
#   'City': 'Austin',
#   'State': 'TX',
#   'Meals Served': 495927.0},
#  {'Restaurant': 'Timberline Steaks and Grille',
#   'Sales': 14362103.0,
#   'Average Check': 37,
#   'City': 'Denver',
#   'State': 'CO',
#   'Meals Served': 553378.0},
#  {'Restaurant': 'Beauty & Essex (Las Vegas)',
#   'Sales': 14130500.0,
#   'Average Check': 99,
#   'City': 'Las Vegas',
#   'State': 'NV',
#   'Meals Served': 150000.0},
#  {'Restaurant': "Carmine's (Atlantic City)",
#   'Sales': 13987843.0,
#   'Average Check': 39,
#   'City': 'Atlantic City',
#   'State': 'NJ',
#   'Meals Served': 129630.0},
#  {'Restaurant': "Junior's (Brooklyn)",
#   'Sales': 13908292.0,
#   'Average Check': 23,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 359000.0},
#  {'Restaurant': 'Quartino Ristorante & Wine Bar',
#   'Sales': 13854856.0,
#   'Average Check': 32,
#   'City': 'Chicago',
#   'State': 'IL',
#   'Meals Served': 394582.0},
#  {'Restaurant': 'Paradise Cove Beach Cafe',
#   'Sales': 13654113.0,
#   'Average Check': 39,
#   'City': 'Malibu',
#   'State': 'CA',
#   'Meals Served': 312050.0},
#  {'Restaurant': 'BOA Steakhouse ',
#   'Sales': 13552485.0,
#   'Average Check': 110,
#   'City': 'West Hollywood',
#   'State': 'CA',
#   'Meals Served': 123204.0},
#  {'Restaurant': "Original Joe's",
#   'Sales': 13177468.0,
#   'Average Check': 45,
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Meals Served': 267533.0},
#  {'Restaurant': 'Founding Farmers (McLean, Va.)',
#   'Sales': 13102742.0,
#   'Average Check': 38,
#   'City': 'McLean',
#   'State': 'VA',
#   'Meals Served': 390104.0},
#  {'Restaurant': 'Siena Tavern',
#   'Sales': 13100000.0,
#   'Average Check': 55,
#   'City': 'Chicago',
#   'State': 'IL',
#   'Meals Served': 238182.0},
#  {'Restaurant': 'Girl & the Goat',
#   'Sales': 12894700.0,
#   'Average Check': 82,
#   'City': 'Chicago',
#   'State': 'IL',
#   'Meals Served': 183000.0},
#  {'Restaurant': 'Tavern on Rush',
#   'Sales': 12884000.0,
#   'Average Check': 72,
#   'City': 'Chicago',
#   'State': 'IL',
#   'Meals Served': 178944.0},
#  {'Restaurant': "Harry & Izzy's Circle Centre",
#   'Sales': 12809921.0,
#   'Average Check': 66,
#   'City': 'Indianapolis',
#   'State': 'IN',
#   'Meals Served': 174166.0},
#  {'Restaurant': "Scoma's",
#   'Sales': 12713394.0,
#   'Average Check': 65,
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Meals Served': 292000.0},
#  {'Restaurant': 'Farmers Fishers Bakers',
#   'Sales': 12572109.0,
#   'Average Check': 37,
#   'City': 'Washington',
#   'State': 'DC',
#   'Meals Served': 371025.0},
#  {'Restaurant': 'Southern Steak & Oyster',
#   'Sales': 12566618.0,
#   'Average Check': 39,
#   'City': 'Nashville',
#   'State': 'TN',
#   'Meals Served': 337920.0},
#  {'Restaurant': 'Big Texan Steak Ranch',
#   'Sales': 12505200.0,
#   'Average Check': 24,
#   'City': 'Amarillo',
#   'State': 'TX',
#   'Meals Served': 478000.0},
#  {'Restaurant': 'Park Avenue Summer (Autumn, Winter, Spring)',
#   'Sales': 12498000.0,
#   'Average Check': 84,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 164531.0},
#  {'Restaurant': 'Farmers & Distillers',
#   'Sales': 12278839.0,
#   'Average Check': 36,
#   'City': 'Washington',
#   'State': 'DC',
#   'Meals Served': 375309.0},
#  {'Restaurant': "Virgil's Real Barbecue",
#   'Sales': 12245998.0,
#   'Average Check': 31,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 251800.0},
#  {'Restaurant': "Carmine's (Washington, D.C.)",
#   'Sales': 12228168.0,
#   'Average Check': 39,
#   'City': 'Washington',
#   'State': 'DC',
#   'Meals Served': 148135.0},
#  {'Restaurant': 'Franciscan Crab Restaurant',
#   'Sales': 12218147.0,
#   'Average Check': 59,
#   'City': 'San Francisco',
#   'State': 'CA',
#   'Meals Served': 240000.0},
#  {'Restaurant': "George's at the Cove",
#   'Sales': 12194000.0,
#   'Average Check': 80,
#   'City': 'La Jolla',
#   'State': 'CA',
#   'Meals Served': 250000.0},
#  {'Restaurant': 'Le Coucou',
#   'Sales': 12187523.0,
#   'Average Check': 95,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 87070.0},
#  {'Restaurant': 'Mi Vida',
#   'Sales': 12032014.0,
#   'Average Check': 38,
#   'City': 'Washington',
#   'State': 'DC',
#   'Meals Served': 226226.0},
#  {'Restaurant': 'Upland',
#   'Sales': 11965564.0,
#   'Average Check': 52,
#   'City': 'New York',
#   'State': 'NY',
#   'Meals Served': 171825.0},
#  {'Restaurant': "Virgil's Real Barbecue",
#   'Sales': 11391678.0,
#   'Average Check': 27,
#   'City': 'Las Vegas',
#   'State': 'NV',
#   'Meals Served': 208276.0}]
